# %% [markdown]
# # Regime Prediction with Machine Learning
#
# *(Phillip Rowe comment):  The Federal Reserve and other Central Banks around the world have taken unprecedented action in providing supportive stimulus since the outbreak of the Covid pandemic. Also, the corrections and bounces in the market appear to occur much more rapidly.  Moreover, the S&P500 and Nasdaq are at near all-time high valuations.  I think it is a fair question, in terms of positioning of investments, "Do recessions matter any more?"*
#
# Based on the database below, which is updated regularly, we are going to build a recession predictor, testing various machine learning models in the process.  The database of monthly macro indicators was downloaded on May 6, 2021, and the most recent entries were for the month of March 2021.
#
# Associated Files for this project
# - **Data_Preprocessing_2021.ipynb** - download monthly economic indicators from Federal Reserve and clean the data
# - **Forecasting_Regimes_with_updated_data.ipynb** -
# - **Random_Forest_Model_Tuning.ipynb**
# - **Scenario_Simulations.ipynb**
#
# References
# - **Part_1_Problem_Description_and_Data_Analysis.ipynb** - more detailed background of the data with academic references
#
# Source Database:
#
# - M. McCracken and S. Ng "FRED-MD: A Monthly Database for Macroeconomic Research", Working Paper, 2015. https://research.stlouisfed.org/econ/mccracken/fred-databases/
# - https://s3.amazonaws.com/files.fred.stlouisfed.org/fred-md/monthly/current.csv
#
# ## Table of Contents:
# &nbsp;&nbsp;1. [Set Up Environment and Read Data](#1)
#
# &nbsp;&nbsp;2. [Data Cleaning](#2)

# %% [markdown]
# ## 1. Set Up Environment and Read Data <a id="1"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import requests
import csv
import os

import time
import datetime

# Anaconda has all these packages
from statsmodels.tsa.stattools import adfuller # to check unit root in time series  

# we don't use any of the following in this notebook
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

import seaborn as sns #for correlation heatmap

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://files.stlouisfed.org/files/htdocs/fred-md/monthly/current.csv'
bigmacro = pd.read_csv(url)
bigmacro = bigmacro.rename(columns={'sasdate':'Date'})
bigmacro = bigmacro.iloc[1:,]
bigmacro = bigmacro.iloc[:-1,]

ts=time.localtime()
day= time.strftime('%Y-%m-%d', ts)
bigmacro.to_csv('current_'+ day + '.csv')
# bigmacro = bigmacro.reset_index()
bigmacro.tail()
# Out:
#           Date        RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# 743  11/1/2020  17355.669  14021.3          118.208  1569672.0  542583.0
# 744  12/1/2020  17386.005  14000.7          117.115  1566283.0  535972.0
# 745   1/1/2021  19120.289  13984.7          120.698  1616846.0  576466.0
# 746   2/1/2021  17741.109  14024.6          119.198  1564397.0  559893.0
# 747   3/1/2021  21368.815  14153.1          123.529        NaN  614449.0
#
#        INDPRO   IPFPNSS   IPFINAL   IPCONGD  ...  DSERRG3M086SBEA  \
# 743  104.8319  101.1674  100.1821  104.8440  ...          120.874
# 744  105.8997  102.4056  101.3916  106.6467  ...          121.328
# 745  106.8853  103.0375  102.1033  106.6088  ...          121.469
# 746  104.0838  101.3872  100.7193  105.6558  ...          121.706
# 747  105.5830  102.2385  101.2736  105.1268  ...          122.230
#
#      CES0600000008  CES2000000008  CES3000000008  UMCSENTx    MZMSL  \
# 743          25.69          29.55          23.10      76.9  21565.0
# 744          25.77          29.64          23.12      80.7  21741.0
# 745          25.85          29.69          23.20      79.0  22000.2
# 746          25.81          29.69          23.25      76.8      NaN
# 747          25.94          29.77          23.28      84.9      NaN
#
#      DTCOLNVHFNM   DTCTHFNM     INVEST  VXOCLSx
# 743    350766.10  733096.73  4609.7215  24.8047
# 744    350336.43  733463.42  4671.9751  21.6803
# 745    354221.61  739961.66  4754.4812  23.7684
# 746    354467.93  740057.00  4815.6771  21.3570
# 747          NaN        NaN  4887.3130  20.7201
#
# [5 rows x 129 columns]

# %%
Recession_periods = pd.read_excel('Recession_Periods.xlsx')
Recession_periods.tail(20)
regime = Recession_periods['Regime'].values

# %%
bigmacro.reindex()
bigmacro.insert(loc=1, column="Regime", value=regime)

# %%
bigmacro.tail()
# 130 columns as of 3/1/2021 data
# Out:
#           Date     Regime        RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  \
# 743  11/1/2020  Recession  17355.669  14021.3          118.208  1569672.0
# 744  12/1/2020  Recession  17386.005  14000.7          117.115  1566283.0
# 745   1/1/2021  Recession  19120.289  13984.7          120.698  1616846.0
# 746   2/1/2021  Recession  17741.109  14024.6          119.198  1564397.0
# 747   3/1/2021  Recession  21368.815  14153.1          123.529        NaN
#
#       RETAILx    INDPRO   IPFPNSS   IPFINAL  ...  DSERRG3M086SBEA  \
# 743  542583.0  104.8319  101.1674  100.1821  ...          120.874
# 744  535972.0  105.8997  102.4056  101.3916  ...          121.328
# 745  576466.0  106.8853  103.0375  102.1033  ...          121.469
# 746  559893.0  104.0838  101.3872  100.7193  ...          121.706
# 747  614449.0  105.5830  102.2385  101.2736  ...          122.230
#
#      CES0600000008  CES2000000008  CES3000000008  UMCSENTx    MZMSL  \
# 743          25.69          29.55          23.10      76.9  21565.0
# 744          25.77          29.64          23.12      80.7  21741.0
# 745          25.85          29.69          23.20      79.0  22000.2
# 746          25.81          29.69          23.25      76.8      NaN
# 747          25.94          29.77          23.28      84.9      NaN
#
#      DTCOLNVHFNM   DTCTHFNM     INVEST  VXOCLSx
# 743    350766.10  733096.73  4609.7215  24.8047
# 744    350336.43  733463.42  4671.9751  21.6803
# 745    354221.61  739961.66  4754.4812  23.7684
# 746    354467.93  740057.00  4815.6771  21.3570
# 747          NaN        NaN  4887.3130  20.7201
#
# [5 rows x 130 columns]

# %% [markdown]
# ## 2. Data Cleaning <a id="2"></a>

# %% [markdown]
# We will follow the steps below to clean data and make it ready for feature selection process.
#
# 1. Remove the variables with missing observations
# 2. Add lags of the variables as additional features
# 3. Test stationarity of time series
# 4. Standardize the dataset

# %%
# remove columns with missing observations
missing_colnames = []
print(bigmacro.shape) # 747 rows x 130 columns before removal of missing columns

for col_name in bigmacro.drop(['Date','Regime'], axis=1):
    observations = len(bigmacro) - bigmacro[col_name].count()
    if (observations > 10):
        print(col_name + ':' + str(observations))
        missing_colnames.append(col_name)

bigmacro = bigmacro.drop(labels=missing_colnames, axis=1)
#  there are a few rows with missing values but they are at the end of the dataset, so there are no missing months
#  in dataset; 59 years and 10 months, starting 1/1/1959, ending 10/2018, or 718 months
bigmacro = bigmacro.dropna(axis=0)

print(bigmacro.shape)  # 120 columns after dropping missing columns; trims a few rows off bottom due to na 
bigmacro.head()
# Out:
# (747, 130)
# PERMIT:12
# PERMITNE:12
# PERMITMW:12
# PERMITS:12
# PERMITW:12
# ACOGNO:398
# ANDENOx:109
# TWEXAFEGSMTHx:168
# UMCSENTx:154
# VXOCLSx:42
# (744, 120)
#        Date  Regime       RPI  W875RX1  DPCERA3M086SBEA    CMRMTSPLx  \
# 1  1/1/1959  Normal  2437.296   2288.8           17.302  292258.8329
# 2  2/1/1959  Normal  2446.902   2297.0           17.482  294429.5453
# 3  3/1/1959  Normal  2462.689   2314.0           17.647  293425.3813
# 4  4/1/1959  Normal  2478.744   2330.3           17.584  299331.6505
# 5  5/1/1959  Normal  2493.228   2345.8           17.796  301372.9597
#
#        RETAILx   INDPRO  IPFPNSS  IPFINAL  ...  DDURRG3M086SBEA  \
# 1  18235.77392  22.6250  23.4581  22.1904  ...           56.918
# 2  18369.56308  23.0681  23.7747  22.3827  ...           56.951
# 3  18523.05762  23.4004  23.9186  22.4925  ...           57.022
# 4  18534.46600  23.8989  24.2641  22.8221  ...           57.080
# 5  18679.66354  24.2589  24.4655  23.0418  ...           57.175
#
#    DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# 1           17.791           11.358           2.13           2.45
# 2           17.798           11.375           2.14           2.46
# 3           17.785           11.395           2.15           2.45
# 4           17.796           11.436           2.16           2.47
# 5           17.777           11.454           2.17           2.48
#
#    CES3000000008  MZMSL  DTCOLNVHFNM  DTCTHFNM   INVEST
# 1           2.04  274.9       6476.0   12298.0  84.2043
# 2           2.05  276.0       6476.0   12298.0  83.5280
# 3           2.07  277.4       6508.0   12349.0  81.6405
# 4           2.08  278.1       6620.0   12484.0  81.8099
# 5           2.08  280.1       6753.0   12646.0  80.7315
#
# [5 rows x 120 columns]

# %%
print(bigmacro.shape)
bigmacro.tail()
# Out:
# (744, 120)
#           Date     Regime        RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  \
# 741   9/1/2020  Recession  17698.892  14029.2          118.656  1564146.0
# 742  10/1/2020  Recession  17573.127  14121.8          118.978  1572500.0
# 743  11/1/2020  Recession  17355.669  14021.3          118.208  1569672.0
# 744  12/1/2020  Recession  17386.005  14000.7          117.115  1566283.0
# 745   1/1/2021  Recession  19120.289  13984.7          120.698  1616846.0
#
#       RETAILx    INDPRO   IPFPNSS   IPFINAL  ...  DDURRG3M086SBEA  \
# 741  549528.0  102.8028   99.4293   98.7850  ...           86.611
# 742  550038.0  103.8958  100.5980   99.5556  ...           86.510
# 743  542583.0  104.8319  101.1674  100.1821  ...           86.292
# 744  535972.0  105.8997  102.4056  101.3916  ...           86.443
# 745  576466.0  106.8853  103.0375  102.1033  ...           86.474
#
#      DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# 741           98.659          120.743          25.49          29.09
# 742           98.558          120.871          25.58          29.40
# 743           98.703          120.874          25.69          29.55
# 744           99.143          121.328          25.77          29.64
# 745          100.118          121.469          25.85          29.69
#
#      CES3000000008    MZMSL  DTCOLNVHFNM   DTCTHFNM     INVEST
# 741          23.01  21249.9    347627.43  730734.42  4425.5453
# 742          22.99  21369.3    348262.68  730398.69  4505.3741
# 743          23.10  21565.0    350766.10  733096.73  4609.7215
# 744          23.12  21741.0    350336.43  733463.42  4671.9751
# 745          23.20  22000.2    354221.61  739961.66  4754.4812
#
# [5 rows x 120 columns]

# %%
# bigmacro Date ended at 1/1/2021 after cleaning out rows with na's.

# Add lags
for col in bigmacro.drop(['Date', 'Regime'], axis=1):
    for n in [3, 6, 9, 12, 18]:   
        bigmacro['{}_{}M_lag'.format(col, n)] = bigmacro[col].shift(n).ffill().values 

# 1 month ahead prediction
bigmacro["Regime"] = bigmacro["Regime"].shift(-1)

bigmacro = bigmacro.dropna(axis=0)
bigmacro.tail(1)
# now only goes to 12/2020, due to shifting regime back one month
# 710 columns vs. 118 data columns before adding lags, 5x118 => 590+120=710
# Out:
#           Date     Regime        RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  \
# 744  12/1/2020  Recession  17386.005  14000.7          117.115  1566283.0
#
#       RETAILx    INDPRO   IPFPNSS   IPFINAL  ...  DTCTHFNM_3M_lag  \
# 744  535972.0  105.8997  102.4056  101.3916  ...        730734.42
#
#      DTCTHFNM_6M_lag  DTCTHFNM_9M_lag  DTCTHFNM_12M_lag  DTCTHFNM_18M_lag  \
# 744        720036.02        721487.58         727441.38          725600.7
#
#      INVEST_3M_lag  INVEST_6M_lag  INVEST_9M_lag  INVEST_12M_lag  \
# 744      4425.5453      4175.7501      3864.5748       3821.8232
#
#      INVEST_18M_lag
# 744       3631.3909
#
# [1 rows x 710 columns]

# %%
# 120 columns before, or 118 minus the Date and Regime
# 118 data columns x 5 diffent lags = 590 additional columns; 
# TOTAL # COLUMNS = 590 + 120 = 710
print(bigmacro.shape)
# Only 725 rows is 19 months less than before, because shifts clipped off 18 months from beginning of time series due to 
# largest time lag, and one month off end of time series
bigmacro['Date'].iloc[[0,-1]]
# Out:
# (725, 710)
# 19      7/1/1960
# 744    12/1/2020
# Name: Date, dtype: object

# %% [markdown]
# Augmented Dickey-Fuller Test can be used to test for stationarity in macroeconomic time series variables. We will use `adfuller` function from `statsmodels` module in Python. More information about the function can be found __[here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html)__.

# %%
# check stationarity
from statsmodels.tsa.stattools import adfuller  # to check unit root in time series 
threshold = 0.01  # significance level
for column in bigmacro.drop(['Date', 'Regime'], axis=1):
    result = adfuller(bigmacro[column])
    if result[1] > threshold:
        print(column)
        bigmacro[column] = bigmacro[column].diff()  # replaces values with diff between current and prior row value
bigmacro = bigmacro.dropna(axis=0)
# Out:
# RPI
# W875RX1
# DPCERA3M086SBEA
# CMRMTSPLx
# RETAILx
# INDPRO
# IPFPNSS
# IPFINAL
# IPCONGD
# IPDCONGD
# IPNCONGD
# IPBUSEQ
# IPMAT
# IPDMAT
# IPNMAT
# IPMANSICS
# IPB51222S
# IPFUELS
# CUMFNS
# HWI
# CLF16OV
# CE16OV
# UEMPMEAN
# UEMPLT5
# UEMP5TO14
# UEMP15OV
# UEMP15T26
# UEMP27OV
# PAYEMS
# USGOOD
# CES1021000001
# USCONS
# MANEMP
# DMANEMP
# NDMANEMP
# SRVPRD
# USTPU
# USWTRADE
# USTRADE
# USFIRE
# CES0600000007
# AWOTMAN
# AWHMAN
# HOUSTNE
# HOUSTMW
# AMDMNOx
# AMDMUOx
# BUSINVx
# ISRATIOx
# M1SL
# M2SL
# M2REAL
# BOGMBASE
# TOTRESNS
# NONBORRES
# BUSLOANS
# REALLN
# NONREVSL
# CONSPI
# S&P 500
# S&P: indust
# S&P div yield
# FEDFUNDS
# CP3Mx
# TB3MS
# TB6MS
# GS1
# GS5
# GS10
# AAA
# BAA
# EXSZUSx
# EXJPUSx
# EXUSUKx
# EXCAUSx
# WPSFD49207
# WPSFD49502
# WPSID61
# WPSID62
# OILPRICEx
# PPICMM
# CPIAUCSL
# CPIAPPSL
# CPITRNSL
# CPIMEDSL
# CUSR0000SAC
# CUSR0000SAD
# CUSR0000SAS
# CPIULFSL
# CUSR0000SA0L2
# CUSR0000SA0L5
# PCEPI
# DDURRG3M086SBEA
# DNDGRG3M086SBEA
# DSERRG3M086SBEA
# CES0600000008
# CES2000000008
# CES3000000008
# MZMSL
# DTCOLNVHFNM
# DTCTHFNM
# INVEST
# RPI_3M_lag
# RPI_6M_lag
# RPI_9M_lag
# RPI_12M_lag
# RPI_18M_lag
# W875RX1_3M_lag
# W875RX1_6M_lag
# W875RX1_9M_lag
# W875RX1_12M_lag
# W875RX1_18M_lag
# DPCERA3M086SBEA_3M_lag
# DPCERA3M086SBEA_6M_lag
# DPCERA3M086SBEA_9M_lag
# DPCERA3M086SBEA_12M_lag
# DPCERA3M086SBEA_18M_lag
# CMRMTSPLx_3M_lag
# CMRMTSPLx_6M_lag
# CMRMTSPLx_9M_lag
# CMRMTSPLx_12M_lag
# CMRMTSPLx_18M_lag
# RETAILx_3M_lag
# RETAILx_6M_lag
# RETAILx_9M_lag
# RETAILx_12M_lag
# RETAILx_18M_lag
# INDPRO_3M_lag
# INDPRO_6M_lag
# INDPRO_9M_lag
# INDPRO_12M_lag
# INDPRO_18M_lag
# IPFPNSS_3M_lag
# IPFPNSS_6M_lag
# IPFPNSS_9M_lag
# IPFPNSS_12M_lag
# IPFPNSS_18M_lag
# IPFINAL_3M_lag
# IPFINAL_6M_lag
# IPFINAL_9M_lag
# IPFINAL_12M_lag
# IPFINAL_18M_lag
# IPCONGD_3M_lag
# IPCONGD_6M_lag
# IPCONGD_9M_lag
# IPCONGD_12M_lag
# IPCONGD_18M_lag
# IPDCONGD_3M_lag
# IPDCONGD_6M_lag
# IPDCONGD_9M_lag
# IPDCONGD_12M_lag
# IPDCONGD_18M_lag
# IPNCONGD_3M_lag
# IPNCONGD_6M_lag
# IPNCONGD_9M_lag
# IPNCONGD_12M_lag
# IPNCONGD_18M_lag
# IPBUSEQ_3M_lag
# IPBUSEQ_6M_lag
# IPBUSEQ_9M_lag
# IPBUSEQ_12M_lag
# IPBUSEQ_18M_lag
# IPMAT_3M_lag
# IPMAT_6M_lag
# IPMAT_9M_lag
# IPMAT_12M_lag
# IPMAT_18M_lag
# IPDMAT_3M_lag
# IPDMAT_6M_lag
# IPDMAT_9M_lag
# IPDMAT_12M_lag
# IPDMAT_18M_lag
# IPNMAT_3M_lag
# IPNMAT_6M_lag
# IPNMAT_9M_lag
# IPNMAT_12M_lag
# IPNMAT_18M_lag
# IPMANSICS_3M_lag
# IPMANSICS_6M_lag
# IPMANSICS_9M_lag
# IPMANSICS_12M_lag
# IPMANSICS_18M_lag
# IPB51222S_3M_lag
# IPB51222S_6M_lag
# IPB51222S_9M_lag
# IPB51222S_12M_lag
# IPB51222S_18M_lag
# IPFUELS_3M_lag
# IPFUELS_6M_lag
# IPFUELS_9M_lag
# IPFUELS_12M_lag
# IPFUELS_18M_lag
# CUMFNS_3M_lag
# CUMFNS_6M_lag
# CUMFNS_12M_lag
# CUMFNS_18M_lag
# HWI_3M_lag
# HWI_6M_lag
# HWI_9M_lag
# HWI_12M_lag
# HWI_18M_lag
# HWIURATIO_9M_lag
# HWIURATIO_18M_lag
# CLF16OV_3M_lag
# CLF16OV_6M_lag
# CLF16OV_9M_lag
# CLF16OV_12M_lag
# CLF16OV_18M_lag
# CE16OV_3M_lag
# CE16OV_6M_lag
# CE16OV_9M_lag
# CE16OV_12M_lag
# CE16OV_18M_lag
# UNRATE_6M_lag
# UNRATE_9M_lag
# UNRATE_12M_lag
# UNRATE_18M_lag
# UEMPMEAN_3M_lag
# UEMPMEAN_6M_lag
# UEMPMEAN_9M_lag
# UEMPMEAN_12M_lag
# UEMPMEAN_18M_lag
# UEMPLT5_3M_lag
# UEMPLT5_6M_lag
# UEMPLT5_9M_lag
# UEMPLT5_12M_lag
# UEMPLT5_18M_lag
# UEMP5TO14_3M_lag
# UEMP5TO14_6M_lag
# UEMP5TO14_9M_lag
# UEMP5TO14_12M_lag
# UEMP5TO14_18M_lag
# UEMP15OV_3M_lag
# UEMP15OV_6M_lag
# UEMP15OV_9M_lag
# UEMP15OV_12M_lag
# UEMP15OV_18M_lag
# UEMP15T26_3M_lag
# UEMP15T26_6M_lag
# UEMP15T26_9M_lag
# UEMP15T26_12M_lag
# UEMP15T26_18M_lag
# UEMP27OV_3M_lag
# UEMP27OV_6M_lag
# UEMP27OV_9M_lag
# UEMP27OV_12M_lag
# UEMP27OV_18M_lag
# CLAIMSx_6M_lag
# PAYEMS_3M_lag
# PAYEMS_6M_lag
# PAYEMS_9M_lag
# PAYEMS_12M_lag
# PAYEMS_18M_lag
# USGOOD_3M_lag
# USGOOD_6M_lag
# USGOOD_9M_lag
# USGOOD_12M_lag
# USGOOD_18M_lag
# CES1021000001_3M_lag
# CES1021000001_6M_lag
# CES1021000001_9M_lag
# CES1021000001_12M_lag
# CES1021000001_18M_lag
# USCONS_3M_lag
# USCONS_6M_lag
# USCONS_9M_lag
# USCONS_12M_lag
# USCONS_18M_lag
# MANEMP_3M_lag
# MANEMP_6M_lag
# MANEMP_9M_lag
# MANEMP_12M_lag
# MANEMP_18M_lag
# DMANEMP_3M_lag
# DMANEMP_6M_lag
# DMANEMP_9M_lag
# DMANEMP_12M_lag
# DMANEMP_18M_lag
# NDMANEMP_3M_lag
# NDMANEMP_6M_lag
# NDMANEMP_9M_lag
# NDMANEMP_12M_lag
# NDMANEMP_18M_lag
# SRVPRD_3M_lag
# SRVPRD_6M_lag
# SRVPRD_9M_lag
# SRVPRD_12M_lag
# SRVPRD_18M_lag
# USTPU_3M_lag
# USTPU_6M_lag
# USTPU_9M_lag
# USTPU_12M_lag
# USTPU_18M_lag
# USWTRADE_3M_lag
# USWTRADE_6M_lag
# USWTRADE_9M_lag
# USWTRADE_12M_lag
# USWTRADE_18M_lag
# USTRADE_3M_lag
# USTRADE_6M_lag
# USTRADE_9M_lag
# USTRADE_12M_lag
# USTRADE_18M_lag
# USFIRE_3M_lag
# USFIRE_6M_lag
# USFIRE_9M_lag
# USFIRE_12M_lag
# USFIRE_18M_lag
# USGOVT_9M_lag
# USGOVT_12M_lag
# USGOVT_18M_lag
# CES0600000007_3M_lag
# CES0600000007_6M_lag
# CES0600000007_9M_lag
# CES0600000007_12M_lag
# CES0600000007_18M_lag
# AWOTMAN_3M_lag
# AWOTMAN_6M_lag
# AWOTMAN_9M_lag
# AWOTMAN_12M_lag
# AWOTMAN_18M_lag
# AWHMAN_3M_lag
# AWHMAN_9M_lag
# AWHMAN_12M_lag
# AWHMAN_18M_lag
# HOUSTNE_3M_lag
# HOUSTNE_6M_lag
# HOUSTNE_9M_lag
# HOUSTNE_12M_lag
# HOUSTNE_18M_lag
# HOUSTMW_3M_lag
# HOUSTMW_6M_lag
# HOUSTMW_9M_lag
# HOUSTMW_12M_lag
# HOUSTMW_18M_lag
# AMDMNOx_3M_lag
# AMDMNOx_6M_lag
# AMDMNOx_9M_lag
# AMDMNOx_12M_lag
# AMDMNOx_18M_lag
# AMDMUOx_3M_lag
# AMDMUOx_6M_lag
# AMDMUOx_9M_lag
# AMDMUOx_12M_lag
# AMDMUOx_18M_lag
# BUSINVx_3M_lag
# BUSINVx_6M_lag
# BUSINVx_9M_lag
# BUSINVx_12M_lag
# BUSINVx_18M_lag
# ISRATIOx_3M_lag
# ISRATIOx_6M_lag
# ISRATIOx_9M_lag
# ISRATIOx_12M_lag
# ISRATIOx_18M_lag
# M1SL_3M_lag
# M1SL_6M_lag
# M1SL_9M_lag
# M1SL_12M_lag
# M1SL_18M_lag
# M2SL_3M_lag
# M2SL_6M_lag
# M2SL_9M_lag
# M2SL_12M_lag
# M2SL_18M_lag
# M2REAL_3M_lag
# M2REAL_6M_lag
# M2REAL_9M_lag
# M2REAL_12M_lag
# M2REAL_18M_lag
# BOGMBASE_3M_lag
# BOGMBASE_6M_lag
# BOGMBASE_9M_lag
# BOGMBASE_12M_lag
# BOGMBASE_18M_lag
# TOTRESNS_3M_lag
# TOTRESNS_6M_lag
# TOTRESNS_9M_lag
# TOTRESNS_12M_lag
# TOTRESNS_18M_lag
# NONBORRES_3M_lag
# NONBORRES_6M_lag
# NONBORRES_9M_lag
# NONBORRES_12M_lag
# NONBORRES_18M_lag
# BUSLOANS_3M_lag
# BUSLOANS_6M_lag
# BUSLOANS_9M_lag
# BUSLOANS_12M_lag
# BUSLOANS_18M_lag
# REALLN_3M_lag
# REALLN_6M_lag
# REALLN_9M_lag
# REALLN_12M_lag
# REALLN_18M_lag
# NONREVSL_3M_lag
# NONREVSL_6M_lag
# NONREVSL_9M_lag
# NONREVSL_12M_lag
# NONREVSL_18M_lag
# CONSPI_3M_lag
# CONSPI_6M_lag
# CONSPI_9M_lag
# CONSPI_12M_lag
# CONSPI_18M_lag
# S&P 500_3M_lag
# S&P 500_6M_lag
# S&P 500_9M_lag
# S&P 500_12M_lag
# S&P 500_18M_lag
# S&P: indust_3M_lag
# S&P: indust_6M_lag
# S&P: indust_9M_lag
# S&P: indust_12M_lag
# S&P: indust_18M_lag
# S&P div yield_3M_lag
# S&P div yield_6M_lag
# S&P div yield_9M_lag
# S&P div yield_12M_lag
# S&P div yield_18M_lag
# FEDFUNDS_3M_lag
# FEDFUNDS_6M_lag
# FEDFUNDS_9M_lag
# FEDFUNDS_12M_lag
# FEDFUNDS_18M_lag
# CP3Mx_3M_lag
# CP3Mx_6M_lag
# CP3Mx_9M_lag
# CP3Mx_12M_lag
# CP3Mx_18M_lag
# TB3MS_3M_lag
# TB3MS_6M_lag
# TB3MS_9M_lag
# TB3MS_12M_lag
# TB3MS_18M_lag
# TB6MS_3M_lag
# TB6MS_6M_lag
# TB6MS_9M_lag
# TB6MS_12M_lag
# TB6MS_18M_lag
# GS1_3M_lag
# GS1_6M_lag
# GS1_9M_lag
# GS1_12M_lag
# GS1_18M_lag
# GS5_3M_lag
# GS5_6M_lag
# GS5_9M_lag
# GS5_12M_lag
# GS5_18M_lag
# GS10_3M_lag
# GS10_6M_lag
# GS10_9M_lag
# GS10_12M_lag
# GS10_18M_lag
# AAA_3M_lag
# AAA_6M_lag
# AAA_9M_lag
# AAA_12M_lag
# AAA_18M_lag
# BAA_3M_lag
# BAA_6M_lag
# BAA_9M_lag
# BAA_12M_lag
# BAA_18M_lag
# EXSZUSx_3M_lag
# EXSZUSx_6M_lag
# EXSZUSx_9M_lag
# EXSZUSx_12M_lag
# EXSZUSx_18M_lag
# EXJPUSx_3M_lag
# EXJPUSx_6M_lag
# EXJPUSx_9M_lag
# EXJPUSx_12M_lag
# EXJPUSx_18M_lag
# EXUSUKx_3M_lag
# EXUSUKx_6M_lag
# EXUSUKx_9M_lag
# EXUSUKx_12M_lag
# EXUSUKx_18M_lag
# EXCAUSx_3M_lag
# EXCAUSx_6M_lag
# EXCAUSx_9M_lag
# EXCAUSx_12M_lag
# EXCAUSx_18M_lag
# WPSFD49207_3M_lag
# WPSFD49207_6M_lag
# WPSFD49207_9M_lag
# WPSFD49207_12M_lag
# WPSFD49207_18M_lag
# WPSFD49502_3M_lag
# WPSFD49502_6M_lag
# WPSFD49502_9M_lag
# WPSFD49502_12M_lag
# WPSFD49502_18M_lag
# WPSID61_3M_lag
# WPSID61_6M_lag
# WPSID61_9M_lag
# WPSID61_12M_lag
# WPSID61_18M_lag
# WPSID62_3M_lag
# WPSID62_6M_lag
# WPSID62_9M_lag
# WPSID62_12M_lag
# WPSID62_18M_lag
# OILPRICEx_3M_lag
# OILPRICEx_6M_lag
# OILPRICEx_9M_lag
# OILPRICEx_12M_lag
# OILPRICEx_18M_lag
# PPICMM_3M_lag
# PPICMM_6M_lag
# PPICMM_9M_lag
# PPICMM_12M_lag
# PPICMM_18M_lag
# CPIAUCSL_3M_lag
# CPIAUCSL_6M_lag
# CPIAUCSL_9M_lag
# CPIAUCSL_12M_lag
# CPIAUCSL_18M_lag
# CPIAPPSL_3M_lag
# CPIAPPSL_6M_lag
# CPIAPPSL_9M_lag
# CPIAPPSL_12M_lag
# CPIAPPSL_18M_lag
# CPITRNSL_3M_lag
# CPITRNSL_6M_lag
# CPITRNSL_9M_lag
# CPITRNSL_12M_lag
# CPITRNSL_18M_lag
# CPIMEDSL_3M_lag
# CPIMEDSL_6M_lag
# CPIMEDSL_9M_lag
# CPIMEDSL_12M_lag
# CPIMEDSL_18M_lag
# CUSR0000SAC_3M_lag
# CUSR0000SAC_6M_lag
# CUSR0000SAC_9M_lag
# CUSR0000SAC_12M_lag
# CUSR0000SAC_18M_lag
# CUSR0000SAD_3M_lag
# CUSR0000SAD_6M_lag
# CUSR0000SAD_9M_lag
# CUSR0000SAD_12M_lag
# CUSR0000SAD_18M_lag
# CUSR0000SAS_3M_lag
# CUSR0000SAS_6M_lag
# CUSR0000SAS_9M_lag
# CUSR0000SAS_12M_lag
# CUSR0000SAS_18M_lag
# CPIULFSL_3M_lag
# CPIULFSL_6M_lag
# CPIULFSL_9M_lag
# CPIULFSL_12M_lag
# CPIULFSL_18M_lag
# CUSR0000SA0L2_3M_lag
# CUSR0000SA0L2_6M_lag
# CUSR0000SA0L2_9M_lag
# CUSR0000SA0L2_12M_lag
# CUSR0000SA0L2_18M_lag
# CUSR0000SA0L5_3M_lag
# CUSR0000SA0L5_6M_lag
# CUSR0000SA0L5_9M_lag
# CUSR0000SA0L5_12M_lag
# CUSR0000SA0L5_18M_lag
# PCEPI_3M_lag
# PCEPI_6M_lag
# PCEPI_9M_lag
# PCEPI_12M_lag
# PCEPI_18M_lag
# DDURRG3M086SBEA_3M_lag
# DDURRG3M086SBEA_6M_lag
# DDURRG3M086SBEA_9M_lag
# DDURRG3M086SBEA_12M_lag
# DDURRG3M086SBEA_18M_lag
# DNDGRG3M086SBEA_3M_lag
# DNDGRG3M086SBEA_6M_lag
# DNDGRG3M086SBEA_9M_lag
# DNDGRG3M086SBEA_12M_lag
# DNDGRG3M086SBEA_18M_lag
# DSERRG3M086SBEA_3M_lag
# DSERRG3M086SBEA_6M_lag
# DSERRG3M086SBEA_9M_lag
# DSERRG3M086SBEA_12M_lag
# DSERRG3M086SBEA_18M_lag
# CES0600000008_3M_lag
# CES0600000008_6M_lag
# CES0600000008_9M_lag
# CES0600000008_12M_lag
# CES0600000008_18M_lag
# CES2000000008_3M_lag
# CES2000000008_6M_lag
# CES2000000008_9M_lag
# CES2000000008_12M_lag
# CES2000000008_18M_lag
# CES3000000008_3M_lag
# CES3000000008_6M_lag
# CES3000000008_9M_lag
# CES3000000008_12M_lag
# CES3000000008_18M_lag
# MZMSL_3M_lag
# MZMSL_6M_lag
# MZMSL_9M_lag
# MZMSL_12M_lag
# MZMSL_18M_lag
# DTCOLNVHFNM_3M_lag
# DTCOLNVHFNM_6M_lag
# DTCOLNVHFNM_9M_lag
# DTCOLNVHFNM_12M_lag
# DTCOLNVHFNM_18M_lag
# DTCTHFNM_3M_lag
# DTCTHFNM_6M_lag
# DTCTHFNM_9M_lag
# DTCTHFNM_12M_lag
# DTCTHFNM_18M_lag
# INVEST_3M_lag
# INVEST_6M_lag
# INVEST_9M_lag
# INVEST_12M_lag
# INVEST_18M_lag

# %%
threshold=0.01 #significance level
for column in bigmacro.drop(['Date','Regime'], axis=1):
    result=adfuller(bigmacro[column])
    if result[1]>threshold:
        print(column)
        bigmacro[column]=bigmacro[column].diff()
bigmacro=bigmacro.dropna(axis=0)
# Out:
# M1SL
# M2SL
# REALLN
# NONREVSL
# CPIAPPSL
# CPIMEDSL
# CUSR0000SAD
# CUSR0000SAS
# DDURRG3M086SBEA
# DSERRG3M086SBEA
# CES0600000008
# CES2000000008
# CES3000000008
# MZMSL
# INVEST
# IPNCONGD 6M lag
# CUMFNS 3M lag
# M1SL 3M lag
# M1SL 6M lag
# M1SL 9M lag
# M1SL 12M lag
# M1SL 18M lag
# M2SL 3M lag
# M2SL 6M lag
# M2SL 9M lag
# M2SL 12M lag
# M2SL 18M lag
# REALLN 3M lag
# REALLN 6M lag
# REALLN 9M lag
# REALLN 12M lag
# REALLN 18M lag
# NONREVSL 3M lag
# NONREVSL 6M lag
# NONREVSL 9M lag
# NONREVSL 12M lag
# NONREVSL 18M lag
# CPIAPPSL 3M lag
# CPIAPPSL 6M lag
# CPIAPPSL 9M lag
# CPIAPPSL 12M lag
# CPIAPPSL 18M lag
# CPIMEDSL 3M lag
# CPIMEDSL 6M lag
# CPIMEDSL 9M lag
# CPIMEDSL 12M lag
# CPIMEDSL 18M lag
# CUSR0000SAD 3M lag
# CUSR0000SAD 6M lag
# CUSR0000SAD 9M lag
# CUSR0000SAD 12M lag
# CUSR0000SAD 18M lag
# CUSR0000SAS 3M lag
# CUSR0000SAS 6M lag
# CUSR0000SAS 9M lag
# CUSR0000SAS 12M lag
# CUSR0000SAS 18M lag
# PCEPI 9M lag
# PCEPI 12M lag
# PCEPI 18M lag
# DDURRG3M086SBEA 3M lag
# DDURRG3M086SBEA 6M lag
# DDURRG3M086SBEA 9M lag
# DDURRG3M086SBEA 12M lag
# DDURRG3M086SBEA 18M lag
# DSERRG3M086SBEA 3M lag
# DSERRG3M086SBEA 6M lag
# DSERRG3M086SBEA 9M lag
# DSERRG3M086SBEA 12M lag
# DSERRG3M086SBEA 18M lag
# CES0600000008 3M lag
# CES0600000008 6M lag
# CES0600000008 9M lag
# CES0600000008 12M lag
# CES0600000008 18M lag
# CES2000000008 3M lag
# CES2000000008 6M lag
# CES2000000008 9M lag
# CES2000000008 12M lag
# CES2000000008 18M lag
# CES3000000008 3M lag
# CES3000000008 6M lag
# CES3000000008 9M lag
# CES3000000008 12M lag
# CES3000000008 18M lag
# MZMSL 3M lag
# MZMSL 6M lag
# MZMSL 9M lag
# MZMSL 12M lag
# MZMSL 18M lag
# INVEST 3M lag
# INVEST 6M lag

# %%
threshold = 0.01  # significance level
for column in bigmacro.drop(['Date', 'Regime'], axis=1):
    result = adfuller(bigmacro[column])
    if result[1] > threshold:
        print(column)
bigmacro = bigmacro.dropna(axis=0)      
# not sure why we do this three times, but we do get just zero columns that are still 
# nonstationary after this
# Out:
# M1SL
# M2SL
# M2REAL
# REALLN
# NONREVSL
# S&P: indust
# CPIAPPSL
# CPIMEDSL
# CUSR0000SAD
# DDURRG3M086SBEA
# DSERRG3M086SBEA
# CES0600000008
# CES2000000008
# CES3000000008
# MZMSL
# INVEST
# DPCERA3M086SBEA_6M_lag
# PAYEMS_6M_lag
# SRVPRD_3M_lag
# SRVPRD_6M_lag
# USTPU_6M_lag
# USWTRADE_6M_lag
# USTRADE_6M_lag
# USFIRE_6M_lag
# AWHMAN_6M_lag
# M1SL_3M_lag
# M1SL_6M_lag
# M1SL_9M_lag
# M1SL_12M_lag
# M1SL_18M_lag
# M2SL_3M_lag
# M2SL_6M_lag
# M2SL_9M_lag
# M2SL_12M_lag
# M2SL_18M_lag
# M2REAL_3M_lag
# M2REAL_6M_lag
# BUSLOANS_3M_lag
# BUSLOANS_6M_lag
# REALLN_3M_lag
# REALLN_6M_lag
# REALLN_9M_lag
# REALLN_12M_lag
# REALLN_18M_lag
# NONREVSL_3M_lag
# NONREVSL_6M_lag
# NONREVSL_9M_lag
# NONREVSL_12M_lag
# NONREVSL_18M_lag
# S&P: indust_3M_lag
# CPIAPPSL_3M_lag
# CPIAPPSL_6M_lag
# CPIAPPSL_9M_lag
# CPIAPPSL_12M_lag
# CPIAPPSL_18M_lag
# CPIMEDSL_3M_lag
# CPIMEDSL_6M_lag
# CPIMEDSL_9M_lag
# CPIMEDSL_12M_lag
# CPIMEDSL_18M_lag
# CUSR0000SAD_3M_lag
# CUSR0000SAD_6M_lag
# CUSR0000SAD_9M_lag
# CUSR0000SAD_12M_lag
# CUSR0000SAD_18M_lag
# CUSR0000SAS_3M_lag
# CUSR0000SAS_6M_lag
# CUSR0000SAS_9M_lag
# CUSR0000SAS_12M_lag
# CUSR0000SAS_18M_lag
# PCEPI_12M_lag
# PCEPI_18M_lag
# DDURRG3M086SBEA_3M_lag
# DDURRG3M086SBEA_6M_lag
# DDURRG3M086SBEA_9M_lag
# DDURRG3M086SBEA_12M_lag
# DDURRG3M086SBEA_18M_lag
# DSERRG3M086SBEA_3M_lag
# DSERRG3M086SBEA_6M_lag
# DSERRG3M086SBEA_9M_lag
# DSERRG3M086SBEA_12M_lag
# DSERRG3M086SBEA_18M_lag
# CES0600000008_6M_lag
# CES0600000008_18M_lag
# CES2000000008_3M_lag
# CES2000000008_6M_lag
# CES2000000008_9M_lag
# CES2000000008_12M_lag
# CES2000000008_18M_lag
# CES3000000008_3M_lag
# CES3000000008_6M_lag
# CES3000000008_9M_lag
# CES3000000008_12M_lag
# CES3000000008_18M_lag
# MZMSL_3M_lag
# MZMSL_6M_lag
# MZMSL_9M_lag
# MZMSL_12M_lag
# MZMSL_18M_lag
# INVEST_3M_lag
# INVEST_6M_lag
# INVEST_9M_lag
# INVEST_12M_lag
# INVEST_18M_lag

# %%
print(bigmacro.shape)   
# Still 710 columns but we have lost two rows because taking .diff() results in one NA after each 
# operation from start of series
bigmacro['Date'].iloc[[0, -1]]
# Out:
# (708, 710)
# 21     9/1/1960
# 728    8/1/2019
# Name: Date, dtype: object

# %%
# Standardize
from sklearn.preprocessing import StandardScaler
features = bigmacro.drop(['Date', 'Regime'], axis=1)
col_names = features.columns

scaler = StandardScaler()
scaler.fit(features)
standardized_features = scaler.transform(features)
# features have been centered and scaled

print(standardized_features.shape)
df = pd.DataFrame(data=standardized_features, columns=col_names)
df.insert(loc=0, column="Date", value=bigmacro['Date'].values)
df.insert(loc=1, column='Regime', value=bigmacro['Regime'].values)
df.shape
# Out:
# (724, 708)
# (724, 710)

# %%
bigmacro.head()
# Out:
#          Date     Regime     RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  \
# 20   8/1/1960  Recession  -4.174     -6.2           -0.017  -369.9733
# 21   9/1/1960  Recession   3.275      0.7            0.087  4748.0925
# 22  10/1/1960  Recession   7.607      7.6            0.089 -5606.3790
# 23  11/1/1960  Recession -11.052    -13.9           -0.064 -2854.8054
# 24  12/1/1960  Recession -11.710    -14.1           -0.225  2270.7833
#
#       RETAILx  INDPRO  IPFPNSS  IPFINAL  ...  DTCTHFNM_3M_lag  \
# 20   64.30177 -0.0277  -0.0575   0.0000  ...            146.0
# 21  -17.63113 -0.2492  -0.2015  -0.1373  ...            257.0
# 22  165.94004 -0.0277   0.1439   0.1098  ...            212.0
# 23 -271.72682 -0.3323  -0.2590  -0.2746  ...            180.0
# 24 -136.90054 -0.4431  -0.3454  -0.3021  ...             74.0
#
#     DTCTHFNM_6M_lag  DTCTHFNM_9M_lag  DTCTHFNM_12M_lag  DTCTHFNM_18M_lag  \
# 20             81.0             85.0             272.0               0.0
# 21             95.0            169.0             186.0              51.0
# 22            174.0              5.0             147.0             135.0
# 23            146.0             81.0              85.0             162.0
# 24            257.0             95.0             169.0             280.0
#
#     INVEST_3M_lag  INVEST_6M_lag  INVEST_9M_lag  INVEST_12M_lag  \
# 20         0.2140        -2.1152        -0.3442         -1.6939
# 21        -0.4994        -1.8067         0.2918         -0.4119
# 22         1.8156        -0.0578        -0.7196         -0.6691
# 23         0.0783         0.2140        -2.1152         -0.3442
# 24         0.9259        -0.4994        -1.8067          0.2918
#
#     INVEST_18M_lag
# 20         -0.6763
# 21         -1.8875
# 22          0.1694
# 23         -1.0784
# 24         -2.0343
#
# [5 rows x 710 columns]

# %%
# Note how the big macro at this point starts with index 20, at 8/1/60, whereas at the beginning of this notebook, it 
# started at 1/1/59
# it ends at 12/1/2020: another indication that this data cannot be used to create a viable trading / investing
# system, because the monthly data is too old by the time a correction and bounce has already taken place.
bigmacro.tail()
# Out:
#           Date     Regime      RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  \
# 740   8/1/2020  Recession -546.709    141.5            1.052     4182.0
# 741   9/1/2020  Recession   95.741    128.5            1.321     9707.0
# 742  10/1/2020  Recession -125.765     92.6            0.322     8354.0
# 743  11/1/2020  Recession -217.458   -100.5           -0.770    -2828.0
# 744  12/1/2020  Recession   30.336    -20.6           -1.093    -3389.0
#
#      RETAILx  INDPRO  IPFPNSS  IPFINAL  ...  DTCTHFNM_3M_lag  DTCTHFNM_6M_lag  \
# 740   4351.0  0.9799   1.3785   1.3432  ...         -1363.66         -2691.83
# 741  10882.0 -0.0857  -0.4140  -0.7672  ...          3870.26         -5046.31
# 742    510.0  1.0930   1.1687   0.7706  ...          4297.44         -3958.16
# 743  -7455.0  0.9361   0.5694   0.6265  ...          2390.39         -1363.66
# 744  -6611.0  1.0678   1.2382   1.2095  ...          4010.57          3870.26
#
#      DTCTHFNM_9M_lag  DTCTHFNM_12M_lag  DTCTHFNM_18M_lag  INVEST_3M_lag  \
# 740           185.12           2203.46          -1135.26        39.9613
# 741          -693.34           1030.96          -4843.41       147.3571
# 742          1784.34           -291.94              6.22       129.6204
# 743         -2691.83            185.12            210.46        62.5068
# 744         -5046.31           -693.34           3106.36        57.6680
#
#      INVEST_6M_lag  INVEST_9M_lag  INVEST_12M_lag  INVEST_18M_lag
# 740         4.0332         6.5273         25.0625         39.7375
# 741        36.2188        23.5833         41.8551         10.0658
# 742       123.8569         2.4996         62.0678         23.2322
# 743        39.9613         4.0332          6.5273         44.3045
# 744       147.3571        36.2188         23.5833         21.6856
#
# [5 rows x 710 columns]

# %%
df.to_csv('current_cleaned_' + day + '.csv', index=False)
